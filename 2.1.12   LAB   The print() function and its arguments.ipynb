# %% [markdown]
# <a href="https://colab.research.google.com/github/Nameless-Karl/python-learning-portfolio/blob/main/2.1.12%20%20%20LAB%20%20%20The%20print()%20function%20and%20its%20arguments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Scenario

# %%
# Modify the first line of code in the editor, using the sep and end keywords, to match the expected output. Use the two print() functions in the editor.

# Don't change anything in the second print() invocation.

# %%
print("Programming","Essentials","in", sep="***", end="...")
print("Python")
# Out:
# Programming***Essentials***in...Python

# %%
print("Programming","Essentials","in", sep="***", end="...")
# Out:
# Programming***Essentials***in...

# %%
print("Python")
# Out:
# Python
